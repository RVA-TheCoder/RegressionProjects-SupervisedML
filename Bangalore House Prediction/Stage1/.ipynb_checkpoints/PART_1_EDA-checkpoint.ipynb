# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## STEP 1 : Data Collection

# %%
filepath_House_Price = r"C:\Users\aakas\PythonStuff\Regression_udemy\resources\Linear_Regression\House_Price.csv"

# %%
houses = pd.read_csv(filepath_House_Price , header = 0 )

# %%
houses.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# 1      Lake        42     YES  0.046146
# 2      None        38     YES  0.045764
# 3      Lake        45     YES  0.047151
# 4      Lake        55     YES  0.039474

# %% [markdown]
# ## STEP 2 : Basic information about data

# %% [markdown]
# #### (i) For finding number of rows and columns

# %%
houses.shape
# Out:
# (506, 19)

# %% [markdown]
# #### (ii) To see number of null values , datatypes and memory usage

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
#  18  parks        506 non-null    float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 75.2+ KB

# %%
houses.isnull().sum()
# Out:
# price          0
# crime_rate     0
# resid_area     0
# air_qual       0
# room_num       0
# age            0
# dist1          0
# dist2          0
# dist3          0
# dist4          0
# teachers       0
# poor_prop      0
# airport        0
# n_hos_beds     8
# n_hot_rooms    0
# waterbody      0
# rainfall       0
# bus_ter        0
# parks          0
# dtype: int64

# %% [markdown]
# #### (iii) Finding Duplicate rows

# %%
houses[houses.duplicated(keep = False)]

# no duplicated rows
# Out:
# Empty DataFrame
# Columns: [price, crime_rate, resid_area, air_qual, room_num, age, dist1, dist2, dist3, dist4, teachers, poor_prop, airport, n_hos_beds, n_hot_rooms, waterbody, rainfall, bus_ter, parks]
# Index: []

# %% [markdown]
# #### (iv) Applying basic statstical computations on the dataset
#
# - Extreme values (min & max values),
# - count of data points,
# - Quantiles,
# - mean ,
# - standard deviation, etc.

# %%
houses.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# std      2.108532    2.108580    2.119797    2.099203    2.164946    7.141062
# min      1.130000    0.920000    1.150000    0.730000   18.000000    1.730000
# 25%      2.270000    1.940000    2.232500    1.940000   19.800000    6.950000
# 50%      3.385000    3.010000    3.375000    3.070000   20.950000   11.360000
# 75%      5.367500    4.992500    5.407500    4.985000   22.600000   16.955000
# max     12.320000   11.930000   12.320000   11.940000   27.400000   37.970000
#
#        n_hos_beds  n_hot_rooms    rainfall       parks
# count  498.000000   506.000000  506.000000  506.000000
# mean     7.899767    13.041605   39.181818    0.054454
# std      1.476683     5.238957   12.513697    0.010632
# min      5.268000    10.057600    3.000000    0.033292
# 25%      6.634500    11.189800   28.000000    0.046464
# 50%      7.999000    12.720000   39.000000    0.053507
# 75%      9.088000    14.170800   50.000000    0.061397
# max     10.876000   101.120000   60.000000    0.086711

# %% [markdown]
# #### (v) Fetching numerical and categorical columns

# %%
from pandas.api.types import is_string_dtype, is_numeric_dtype

num_list = []
cat_list = []

for column in houses:
    
    if is_numeric_dtype(houses[column]):
        num_list.append(column)
        
    elif is_string_dtype(houses[column]):
        cat_list.append(column)



print('Numerical attributes : ',num_list,'\n')

print('Categorical attributes : ',cat_list)
# Out:
# Numerical attributes :  ['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age', 'dist1', 'dist2', 'dist3', 'dist4', 'teachers', 'poor_prop', 'n_hos_beds', 'n_hot_rooms', 'rainfall', 'parks']
#
# Categorical attributes :  ['airport', 'waterbody', 'bus_ter']

# %%
houses.columns
# Out:
# Index(['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age',
#        'dist1', 'dist2', 'dist3', 'dist4', 'teachers', 'poor_prop', 'airport',
#        'n_hos_beds', 'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter',
#        'parks'],
#       dtype='object')

# %% [markdown]
# #### (vi) finding unique values in the categorical attributes

# %%
for col in cat_list:
    
    print(f"{col} : " ,houses[col].unique())
# Out:
# airport :  ['YES' 'NO']
# waterbody :  ['River' 'Lake' 'None' 'Lake and River']
# bus_ter :  ['YES']

# %% [markdown]
# ## STEP 3 : UNIVARIATE ANALYSIS

# %% [markdown]
# ### (i) Histogram-kde  for Numerical  attributes.

# %%
total_size1 = len(num_list) 

n_cols1 = 2
n_rows1 = int(np.ceil(total_size1/n_cols1))

fig1,axes1 = plt.subplots(nrows = n_rows1 ,ncols = n_cols1 , figsize = (12,18))

i = 0
j = 0

fig1.suptitle("HISTOGRAM \n", fontweight="bold" ,fontsize=20)
# fig1.tight_layout()

for col in num_list:

    
    axes2 = sns.histplot(ax = axes1[i,j], data = houses , x = col ,kde =  True ,bins = 20)
    fig1.tight_layout()
    
    axes2.set_title(f"{col}",fontweight="bold" ,fontsize=12)
    
    if j == n_cols1 -1:
        
        i +=1
        j = 0
        
    else :
        j+=1

# %% [markdown]
# ### Insights from above histogram

# %% [markdown]
# - **room_num**  : normally distributed.
#
# - **dist1,dist2,dist3 , dist4**,**poor_prop , **air_qual** and parks** :  features are right skewed normally distributed data.

# %% [markdown]
# ### (ii) countplot for  categorical attributes

# %%
total_size2 = len(cat_list)

n_cols2 = 2
n_rows2 = int(np.ceil(total_size2/n_cols2))

fig3,axes3 = plt.subplots(nrows = n_rows2 ,ncols = n_cols2 , figsize = (10,6))
fig3.tight_layout()

i = 0
j = 0

fig3.suptitle("COUNTPLOTS \n", fontweight="bold" ,fontsize=20)

for col in cat_list:
    
    fig3.tight_layout()

    axes4 = sns.countplot(ax = axes3[i,j], data = houses , x = col ,hue = col )
     
    axes4.set(xticklabels=[])
    axes4.set(xlabel=None)
    axes4.set_title(f"{col}",fontweight="bold" ,fontsize=12)
    
    axes4.set(ylabel='Frequency')
    axes4.grid(visible=True ,axis ='y')
                    
        
    if j == n_cols2 -1 :
        
        i +=1
        j = 0
        
    else :
        j += 1

# %% [markdown]
# ### (iii) Boxplot for numerical attributes for finding the outleirs

# %% [markdown]
# - **room_num**  : normally distributed.
#
# - **dist1,dist2,dist3 , dist4**,**poor_prop , **air_qual** and parks** :  features are right skewed normally distributed data.

# %%
# num_list

# %%
# normally , almost normally or skew normally distributed columns.
cols = ['air_qual' ,'room_num','dist1','dist2','dist3' , 'dist4','poor_prop','parks']

# %%
total_size_num = len(cols) 
 
n_cols=2
n_rows= int(np.ceil(total_size_num/n_cols))

fig5, axes5 = plt.subplots(nrows=n_rows, ncols=n_cols , figsize = (12,12),)

i = 0
j = 0


fig5.suptitle("BOXPLOTS\n", fontweight="bold" ,fontsize=20)
fig5.tight_layout()

for col in cols:
    
    axes6 = houses[col].plot.box(ax = axes5[i,j],vert = 0)
    axes6.set_title(f"{col}",fontweight="bold" ,fontsize=12)
    
    axes6.set(yticklabels=[])
    fig5.tight_layout()
    
    if j == n_cols-1:
        i = i + 1
        j = 0
    
    else:
        j = j + 1

# %% [markdown]
# ### Insights

# %% [markdown]
# - **room_num**  feature has outliers.
# - **dist1**,**dist2**,**dist3** & **dist4** features have outliers.
# - **poor_prop** & **parks** features have outliers.

# %% [markdown]
# ## STEP - 4 : Bi-Variate Analysis

# %% [markdown]
# - **Bivariate analysis** is categorized into these three conditions to address various combinations of
#   numerical variables and categorical variables.

# %% [markdown]
# ### (i) Numerical vs. Numerical → heat map or pairplot

# %%
correlation = houses.corr(numeric_only =True)
plt.figure(figsize = (12,12) ,dpi = 120 , layout = 'tight' )
sns.heatmap(correlation,cmap = 'GnBu' , annot = True)

plt.show()

# %% [markdown]
# ### Insights

# %% [markdown]
# - **dist1** is highly correlated with **dist2, dist3  & dist4** with correlation coefficent >=0.99
# - **air_quality** is highly correlated with **parks** with Correlation coefficient = 0.92

# %%
houses.corrwith(other = houses['price'] ,numeric_only= True).sort_values(ascending=False, 
                                                                         key=lambda x: abs(x))
# Out:
# price          1.000000
# poor_prop     -0.740836
# room_num       0.696304
# teachers       0.505655
# resid_area    -0.484754
# air_qual      -0.429300
# parks         -0.391574
# crime_rate    -0.389582
# age           -0.377999
# dist1          0.251355
# dist2          0.249459
# dist4          0.248200
# dist3          0.246650
# n_hos_beds     0.109646
# rainfall      -0.047426
# n_hot_rooms    0.023122
# dtype: float64

# %%
# num_list

# %%
num_list_test = num_list.copy()

# %%
num_list_test.remove('price')

# %%
# num_list_test

# %%
num_list_test = num_list.copy()
num_list_test.remove('price')
#num_list_test

# num_plots2 = len(num_list_test)

n_cols = 2
n_rows = int(np.ceil(len(num_list_test)/ n_cols))


fig11, axes11 = plt.subplots(nrows=n_rows, ncols=n_cols , figsize = (12,24),)

fig11.suptitle("ScatterPlots -  Numerical Variable\n\n", fontweight="bold" ,fontsize=20)

fig11.tight_layout()

i = 0
j = 0


for column in num_list_test : 
        
    fig11.tight_layout()
    
    axes12 = sns.scatterplot(ax = axes11[i,j],data = houses , y = 'price' ,
                            x = column, 
                            )

    axes12.set_title(f"Price vs : {column}" , fontsize = 14 , fontweight = 'bold')

    if j == n_cols2-1:
        i = i + 1
        j = 0

    else:
        j = j + 1

# %% [markdown]
# ### Insights

# %% [markdown]
# - **price** & **crime_rate** vs has power law distribution
# - **price** & **poor_prop** vs has power law distribution

# %% [markdown]
# ### (ii) Numerical versus categorical pairplot

# %%
# cat_list

# %%
# hue_list  = ['airport', 'waterbody']

# %%
# numercal_list = ['resid_area' , 'room_num' ,'teachers' , 'poor_prop']

# %%
# num_plots = len(numercal_list)*len(hue_list)

# %%
# num_plots

# %%
cat_list
# Out:
# ['airport', 'waterbody', 'bus_ter']

# %% [markdown]
#     poor_prop     -0.740836
#     room_num       0.696304
#     teachers       0.505655
#     resid_area    -0.484754
#     air_qual      -0.429300
#     parks         -0.391574
#     crime_rate    -0.389582
#     age           -0.377999

# %%
hue_list  = ['airport', 'waterbody']

numerical_list = ['resid_area' , 'room_num' ,'teachers' , 'poor_prop',
                  'air_qual','parks','crime_rate','age']

num_plots = len(numerical_list)*len(hue_list)

n_cols = 2
n_rows = int(np.ceil(num_plots/ n_cols))


fig9, axes9 = plt.subplots(nrows=n_rows, ncols=n_cols , figsize = (12,22),)
fig9.suptitle("SCATTERPLOTS WITH HUE\n", fontweight="bold" ,fontsize=20)
fig9.tight_layout()

i = 0
j = 0

for column in numerical_list : 
    
    for hue in hue_list:
        fig9.tight_layout()
        axes10 = sns.scatterplot(ax = axes9[i,j],data = houses , y = 'price' ,
                                x = column, 
                                hue= hue , 
                                palette= 'deep' , alpha = 0.6)

        axes10.set_title(f"Hue : {hue.upper()}" , fontsize = 14 , fontweight = 'bold')

        if j == n_cols2-1:
            i = i + 1
            j = 0

        else:
            j = j + 1

# %% [markdown]
# ## STEP - 5 : Multi-Variate Analysis

# %% [markdown]
# #### From correlation analysis following conclusions have been made:
#
#
# - **dist1** is highly correlated with **dist2**, **dist3** & **dist4** with correlation coefficent >=0.99
# - **air_quality** is highly correlated with **parks** with Correlation coefficient = 0.92
#
# #### so checking them for multicollinarity
#
# - **Threshold value** of VIF is : VIF >= 10 for dropping a column

# %%
# houses.columns

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %% [markdown]
# #### Syntax : variance_inflation_factor(exog, exog_idx)
#
# - **Explanation :**
#
#     One recommendation is that if VIF is greater than 5, then the explanatory variable given by
#
#     'exog_idx' is highly collinear with the other explanatory variables, and
#
#     the parameter estimates will have large standard errors because of this.

# %%
df_houses = houses.copy()

# %%
len(df_houses)
# Out:
# 506

# %%
df_houses.dropna(inplace = True)

# %%
len(df_houses)
# Out:
# 498

# %%
mc_feat = ['resid_area' , 'room_num' ,'teachers' , 'poor_prop','dist1', 
           'dist2', 'dist3', 'dist4','parks','air_qual']

# %%
# Defining custom function for calculating VIF

def compute_vif(feature_list ,dataframe):
    
    X = dataframe[feature_list]
    
    # Dropping any NaN values
    X.dropna(inplace = True)
    
    # Adding constant column in X
    X  = add_constant(X ,prepend=True)
    
    # Creating DF for storing VIF values
    vif = pd.DataFrame()
    vif['variable'] = X.columns
    
    
    vif['VIF'] = [variance_inflation_factor(X.values ,i) for i in range(X.shape[1])]
    
    vif = vif[vif['variable'] != 'const']
    
    return vif

# %%
# mc_feat

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
compute_vif(feature_list = mc_feat ,dataframe = df_houses)
# Out:
#       variable         VIF
# 1   resid_area    3.167443
# 2     room_num    1.740857
# 3     teachers    1.318547
# 4    poor_prop    2.424076
# 5        dist1  314.319983
# 6        dist2  358.071532
# 7        dist3  345.717764
# 8        dist4   96.256746
# 9        parks    6.207035
# 10    air_qual    8.509740

# %%
# lets remove 'dist2' column

mc_feat.remove('dist2')

# %%
mc_feat
# Out:
# ['resid_area',
#  'room_num',
#  'teachers',
#  'poor_prop',
#  'dist1',
#  'dist3',
#  'dist4',
#  'parks',
#  'air_qual']

# %%
compute_vif(feature_list = mc_feat , dataframe  = df_houses)
# Out:
#      variable         VIF
# 1  resid_area    3.166202
# 2    room_num    1.740211
# 3    teachers    1.317630
# 4   poor_prop    2.421969
# 5       dist1  251.737778
# 6       dist3  254.918565
# 7       dist4   94.275610
# 8       parks    6.205139
# 9    air_qual    8.495325

# %%
# lets remove 'dist3' column

mc_feat.remove('dist3')

# %%
compute_vif(feature_list = mc_feat , dataframe  = df_houses)
# Out:
#      variable        VIF
# 1  resid_area   3.163197
# 2    room_num   1.725598
# 3    teachers   1.313819
# 4   poor_prop   2.417414
# 5       dist1  86.328871
# 6       dist4  85.309646
# 7       parks   6.138321
# 8    air_qual   8.483502

# %%
# lets remove 'dist1' column

mc_feat.remove('dist1')

# %%
compute_vif(feature_list = mc_feat , dataframe  = df_houses)
# Out:
#      variable       VIF
# 1  resid_area  3.163029
# 2    room_num  1.725595
# 3    teachers  1.309749
# 4   poor_prop  2.417388
# 5       dist4  2.706796
# 6       parks  6.135967
# 7    air_qual  8.428561

# %%
# lets remove 'air_qual' column
# correlation coefficent of 'price' with 'air_qual'= -0.429300
# correlation coefficent of 'price' with 'parks' = -0.391574
# so be careful

mc_feat.remove('parks')

# %%
compute_vif(feature_list = mc_feat , dataframe  = df_houses)
# Out:
#      variable       VIF
# 1  resid_area  3.160871
# 2    room_num  1.725368
# 3    teachers  1.309017
# 4   poor_prop  2.416106
# 5       dist4  2.706672
# 6    air_qual  3.514231

# %% [markdown]
# #### Conclusion : we have to do feature enginnering
# - we can drop the **dist2** , **dist3** , **dist1** columns. (if needed)
# - **parks** and **air_qual** columns are highly correlated ,so we can drop **parks** column
#    because it is less correlated to **price** column compared to **air_qual** column.
